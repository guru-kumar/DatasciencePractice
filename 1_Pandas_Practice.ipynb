# %% [markdown]
# <a href="https://colab.research.google.com/github/guru-kumar/DatasciencePractice/blob/main/1_Pandas_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/Salaries.csv")

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.head(10)
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350
# 9       Prof          A   51       51  Male   57800

# %%
df.head(20)
# Out:
#          rank discipline  phd  service   sex  salary
# 0        Prof          B   56       49  Male  186960
# 1        Prof          A   12        6  Male   93000
# 2        Prof          A   23       20  Male  110515
# 3        Prof          A   40       31  Male  131205
# 4        Prof          B   20       18  Male  104800
# 5        Prof          A   20       20  Male  122400
# 6   AssocProf          A   20       17  Male   81285
# 7        Prof          A   18       18  Male  126300
# 8        Prof          A   29       19  Male   94350
# 9        Prof          A   51       51  Male   57800
# 10       Prof          B   39       33  Male  128250
# 11       Prof          B   23       23  Male  134778
# 12   AsstProf          B    1        0  Male   88000
# 13       Prof          B   35       33  Male  162200
# 14       Prof          B   25       19  Male  153750
# 15       Prof          B   17        3  Male  150480
# 16   AsstProf          B    8        3  Male   75044
# ...

# %%
df.head(50)
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df.head(5)
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=78, step=1),
#  Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')]

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 468

# %%
df.shape
# Out:
# (78, 6)

# %%
df.values

# %% [markdown]
# **Methods**

# %%
df.head(10)

# %%
df.describe()

# %%
df.min()
# Out:
# rank          AssocProf
# discipline            A
# phd                   1
# service               0
# sex              Female
# salary            57800
# dtype: object

# %%
df.max()

# %%
df.sample(10)

# %%
dir(df)

# %%
df.head(10)
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350
# 9       Prof          A   51       51  Male   57800

# %%
df.std()
# Out:
# phd           12.498425
# service       12.139768
# salary     28293.661022
# dtype: float64

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df1 = df.head(50)

# %%
df1.mean()
# Out:
# phd            21.52
# service        17.60
# salary     113789.14
# dtype: float64

# %%
df.mean()
# Out:
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
df.head(50).mean()
# Out:
# phd            21.52
# service        17.60
# salary     113789.14
# dtype: float64

# %%
df['phd'].describe()
# Out:
# count    78.000000
# mean     19.705128
# std      12.498425
# min       1.000000
# 25%      10.250000
# 50%      18.500000
# 75%      27.750000
# max      56.000000
# Name: phd, dtype: float64

# %%
df['phd'].count()
# Out:
# 78

# %%
df['phd'].mean()
# Out:
# 19.705128205128204

# %%
df_rank = df.groupby(['rank'])

# %%
df_rank.mean()
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
df_rank['salary'].mean()
# Out:
# rank
# AssocProf     91786.230769
# AsstProf      81362.789474
# Prof         123624.804348
# Name: salary, dtype: float64

# %%
df_rank[['salary', 'service']].mean()
# Out:
#                   salary    service
# rank
# AssocProf   91786.230769  11.307692
# AsstProf    81362.789474   2.210526
# Prof       123624.804348  21.413043

# %%
df[(df['salary'] > 120000) & (df['phd'] >= 20)]
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 3   Prof          A   40       31    Male  131205
# 5   Prof          A   20       20    Male  122400
# 10  Prof          B   39       33    Male  128250
# 11  Prof          B   23       23    Male  134778
# 13  Prof          B   35       33    Male  162200
# 14  Prof          B   25       19    Male  153750
# 19  Prof          A   29       27    Male  150500
# 26  Prof          A   38       19    Male  148750
# 27  Prof          A   45       43    Male  155865
# 29  Prof          B   21       20    Male  123683
# 31  Prof          B   22       21    Male  155750
# 35  Prof          B   28       23    Male  126933
# 36  Prof          B   45       45    Male  146856
# 40  Prof          A   39       36  Female  137000
# 44  Prof          B   23       19  Female  151768
# 45  Prof          B   25       25  Female  140096
# 51  Prof          B   20       14  Female  127512
# ...

# %%
(df['phd'] >= 20) & (df['discipline'] == "A")
# Out:
# 0     False
# 1     False
# 2      True
# 3      True
# 4     False
#       ...
# 73    False
# 74    False
# 75    False
# 76     True
# 77     True
# Length: 78, dtype: bool

# %%
df[(df['phd'] >= 20) & (df['discipline'] == "A")]
# Out:
#          rank discipline  phd  service     sex  salary
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 19       Prof          A   29       27    Male  150500
# 21       Prof          A   33       30    Male  103106
# 24       Prof          A   30       23    Male   91100
# 26       Prof          A   38       19    Male  148750
# 27       Prof          A   45       43    Male  155865
# 32       Prof          A   27       19    Male  103275
# 37       Prof          A   20        8    Male  102000
# 40       Prof          A   39       36  Female  137000
# 54  AssocProf          A   25       22  Female   62884
# 63       Prof          A   29       27  Female   91000
# ...

# %%
df.iloc[:, 0:3]
# Out:
#          rank discipline  phd
# 0        Prof          B   56
# 1        Prof          A   12
# 2        Prof          A   23
# 3        Prof          A   40
# 4        Prof          B   20
# ..        ...        ...  ...
# 73       Prof          B   18
# 74  AssocProf          B   19
# 75       Prof          B   17
# 76       Prof          A   28
# 77       Prof          A   23
#
# [78 rows x 3 columns]

# %%
df.iloc[0:2,:]
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000

# %%
df.iloc[0:50, [2,3]]
# Out:
#     phd  service
# 0    56       49
# 1    12        6
# 2    23       20
# 3    40       31
# 4    20       18
# 5    20       20
# 6    20       17
# 7    18       18
# 8    29       19
# 9    51       51
# 10   39       33
# 11   23       23
# 12    1        0
# 13   35       33
# 14   25       19
# 15   17        3
# 16    8        3
# 17    4        0
# 18   19        7
# 19   29       27
# 20    4        4
# 21   33       30
# 22    4        2
# 23    2        0
# 24   30       23
# 25   35       31
# 26   38       19
# 27   45       43
# 28    7        2
# 29   21       20
# 30    9        7
# 31   22       21
# 32   27       19
# 33   18       18
# 34   12        8
# 35   28       23
# 36   45       45
# 37   20        8
# 38    4        3
# 39   18       18
# 40   39       36
# 41   13        8
# 42    4        2
# 43    5        0
# 44   23       19
# 45   25       25
# 46   11        3
# 47   11       11
# 48   17       17
# 49   17       18
